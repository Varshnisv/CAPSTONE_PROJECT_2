# %% [markdown]
# <a href="https://colab.research.google.com/github/Varshnisv/CAPSTONE_PROJECT_2/blob/main/CAPSTONE_PROJECT_2_PLAYSTORE_REVIEW_ANALYSIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -**  VARSHNI S V

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.
# Dataset Overview
# The project employs two core datasets: one holding extensive information about various apps accessible on the Google Play Store, and another collecting consumer reviews for these apps. The applications dataset includes important parameters like category, rating, size, and number of installations, whereas the reviews dataset contains qualitative feedback from consumers. By merging these statistics, we can conduct a thorough analysis to identify patterns and trends that affect app performance.
#
# Data Cleanup and Preparation
# Data quality is critical for useful analysis, requiring meticulous cleaning and preparation. The first phase entailed dealing with missing values, notably in crucial columns such as 'Rating' and 'Size.'
#
# Key insights
# The investigation yielded some useful insights:
#
# Popular Categories: The study found key categories with a large number of installs and positive evaluations, alerting developers to profitable market sectors.
# Free vs. Paid Applications: Comparing the performance of free and premium applications revealed information about user preferences and the efficiency of monetisation techniques.
# Size and Performance: Understanding the influence of app size on ratings and installations may help developers optimise their apps for more user engagement.
#
# Conclusion
# This project is a detailed study of Play Store app data, providing developers with useful information in today's competitive mobile app environment. Using data manipulation tools and visualisations, we discovered patterns that influence app success. The findings of this study not only improve our understanding of user preferences, but also help developers make strategic decisions in app design, marketing, and user engagement. The study's findings can help developers optimise their applications for better performance and customer happiness in the Android marketplace. As the app ecosystem evolves, continuous analysis of user data will be critical to sustaining competitiveness and success.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer
# The major goal of this project is to unearth actionable insights from Play Store app data that will help developers create successful Android applications. We want to uncover critical components that lead to app engagement and performance by analysing characteristics including app categories, ratings, size, and user reviews. The findings of this research will assist developers to make more informed decisions regarding app design, feature implementation, and marketing tactics, allowing them to grab a greater market share and improve user happiness. Understanding user sentiment from reviews can also give vital input for app development's constant improvement and innovation efforts.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
#Pandas lib is imported as variable pd
import pandas as pd
#Numpy lib is imported as variable np
import numpy as np
#matplotlib and seaborn is imported for datavizualization purpose
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
App_DATA = pd.read_csv('Play Store Data.csv')
Rev_DATA = pd.read_csv('User Reviews.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
print("App_Data 5 rows are viewed")
print(App_DATA.head())
print("\n Rev_Data 5 rows are viewed")
print(Rev_DATA.head())
# Out:
# App_Data 5 rows are viewed
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
app_shape = App_DATA.shape
review_shape = Rev_DATA.shape
print(app_shape)
print(review_shape)
# Out:
# (10841, 13)
# (64295, 5)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
print("\nApp Data Info:")
App_DATA.info()  # Display detailed information about the App DATASET

print("\nReview Data Info:")
Rev_DATA.info()  # Display detailed information about the Rev DATASET
# Out:
# App Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB
#
# Review Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
App_dup = App_DATA.duplicated().sum()
Rev_dup = Rev_DATA.duplicated().sum()

# Displaying the duplicate counts in both the dataset
print(App_dup)
print(Rev_dup)
# Out:
# 483
# 33616

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
App_miss = App_DATA.isnull().sum()
Rev_miss = Rev_DATA.isnull().sum()

# Display the missing values count for all Column
print("Missing Value count of App_DATA")
print(App_miss[App_miss > 0])

print("Missing Value count of Rev_DATA")
print(Rev_miss[Rev_miss > 0])
# Out:
# Missing Value count of App_DATA
# Rating            1474
# Type                 1
# Content Rating       1
# Current Ver          8
# Android Ver          3
# dtype: int64
# Missing Value count of Rev_DATA
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
# Bar plot for missing values in Apps Data
App_miss = App_DATA.isnull().sum()

plt.figure(figsize=(10, 6))
App_miss[App_miss > 0].plot(kind='bar', color='skyblue')
plt.title('Missing Values Count in App Data')
plt.xlabel('Columns')
plt.ylabel('Count of Missing Values')
plt.show()

# Bar plot for missing values in Reviews Data
Rev_miss = Rev_DATA.isnull().sum()

plt.figure(figsize=(10, 6))
Rev_miss[Rev_miss > 0].plot(kind='bar', color='lightcoral')
plt.title('Missing Values Count in Rev Data')
plt.xlabel('Columns')
plt.ylabel('Count of Missing Values')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer
# 1. Format of the dataset
# The app dataset includes various key information for each program, including Category, Rating, Size, Installs, Price, Genres, and Last Updated, among others. These features provide a complete overview of each app's details.
# The customer reviews dataset contains information on individual app reviews, including App, Sentiment, Sentiment_Polarity, and Sentiment_Subjectivity. These features aid in the analysis of user feedback and the determination of overall attitudes towards apps.
# 2. Column and Row Count
# After importing the datasets:
# The applications dataset has a large number of rows 10,841 and around 13 columns.
# The reviews dataset comprises around 64,295 rows with 5 columns.
# This demonstrates that we have a diversified dataset for both app characteristics and user evaluations, allowing for in-depth examination of app performance.
# 3.Data Types:
# The applications dataset has mixed data types:
# The numerical columns are Rating, Size, and Price.
# The categorical columns are Category, Content Rating, Genres, and Last Updated.
# The reviews dataset contains both numerical and category data:
# The Sentiment_Polarity and Sentiment_Subjectivity columns are numerical, whereas Sentiment is categorical.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
#First for App_DATA.csv
print(App_DATA.columns)
#Second for Rev_DATA.scv
print(Rev_DATA.columns)
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
# Dataset Describe
#Dataset describing for App_DATA
print(App_DATA.describe())
#Dataset describing for Rev_DATA
print(Rev_DATA.describe())
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
# Check unique values count for each Variable that is columns in the Apps dataset
print("Unique values count in App Dataset:")
print(App_DATA.nunique())
# Check unique values count for each Variable that is columns in the Review dataset
print("Unique values count in Rev Dataset:")
print(Rev_DATA.nunique())
# Out:
# Unique values count in App Dataset:
# App               9660
# Category            34
# Rating              40
# Reviews           6002
# Size               462
# Installs            22
# Type                 3
# Price               93
# Content Rating       6
# Genres             120
# Last Updated      1378
# Current Ver       2832
# Android Ver         33
# dtype: int64
# Unique values count in Rev Dataset:
# App                        1074
# Translated_Review         27994
# Sentiment                     3
# Sentiment_Polarity         5410
# Sentiment_Subjectivity     4474
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Step 1 Handle Missing Values
App_DATA = App_DATA[~App_DATA['Installs'].str.contains('Free')]
App_DATA.dropna(subset=['Rating', 'Size'], inplace=True)
App_DATA['Rating'].fillna(App_DATA['Rating'].mean(), inplace=True)

#Step 2 Change or convert all datatypes in App dataset
App_DATA['Installs'] = App_DATA['Installs'].str.replace('[+,]', '', regex=True).astype(int)
App_DATA['Price'] = App_DATA['Price'].str.replace('$', '').astype(float)
App_DATA['Size'] = App_DATA['Size'].replace('Varies with device', np.nan)
App_DATA['Size'] = App_DATA['Size'].str.replace('M', '').str.replace('k', '').astype(float)
App_DATA['Reviews'] = App_DATA['Reviews'].astype(int)
# Out:
# <ipython-input-13-bd7d0036aa75>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   App_DATA.dropna(subset=['Rating', 'Size'], inplace=True)
# <ipython-input-13-bd7d0036aa75>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   App_DATA['Rating'].fillna(App_DATA['Rating'].mean(), inplace=True)
# ...

# %%
#Step 3
# Feature Engineering
App_DATA['Is_Free'] = App_DATA['Type'].apply(lambda x: 1 if x == 'Free' else 0)

# Remove Duplicates
App_DATA.drop_duplicates(inplace=True)

# Clean Customer Reviews Data
Rev_DATA.drop_duplicates(inplace=True)

# %%
# Merging Apps and Reviews Data
merged_data = pd.merge(App_DATA, Rev_DATA, on='App', how='inner')

# Handle missing values in the merged data
merged_data.fillna({'Sentiment': 'Neutral', 'Sentiment_Polarity': 0, 'Sentiment_Subjectivity': 0}, inplace=True)

# Dataset is now ready for analysis!
print("\nApps Dataset after cleaning and transformation:")
print(App_DATA.info())

print("\nCustomer Reviews Dataset after cleaning:")
print(Rev_DATA.info())

print("\nMerged Dataset (if required for analysis):")
print(merged_data.info())
# Out:
# Apps Dataset after cleaning and transformation:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8892 entries, 0 to 10840
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8892 non-null   object
#  1   Category        8892 non-null   object
#  2   Rating          8892 non-null   float64
#  3   Reviews         8892 non-null   int64
#  4   Size            7424 non-null   float64
#  5   Installs        8892 non-null   int64
#  6   Type            8892 non-null   object
#  7   Price           8892 non-null   float64
#  8   Content Rating  8892 non-null   object
#  9   Genres          8892 non-null   object
#  10  Last Updated    8892 non-null   object
#  11  Current Ver     8888 non-null   object
#  12  Android Ver     8890 non-null   object
#  13  Is_Free         8892 non-null   int64
# dtypes: float64(3), int64(3), object(8)
# memory usage: 1.0+ MB
# None
#
# ...

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(16, 8))
sns.histplot(App_DATA['Rating'], bins=20, kde=True)
plt.title('App Ratings')
plt.xlabel('Ratings')
plt.ylabel('Count of them')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer This Chart help the users to understand the reviews over rating clearly

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer
# According to the figure, the majority of apps have good ratings (around 4-5), showing overall favourable customer satisfaction throughout the Play Store.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer
# Yes it is because, it is focusing on user experience growth

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
plt.figure(figsize=(12, 8))
category_installs = App_DATA.groupby('Category')['Installs'].sum().sort_values(ascending=False)
sns.barplot(x=category_installs.index, y=category_installs.values)
plt.title('Overall Installs by Category')
plt.xticks(rotation=90)
plt.xlabel('Categories')
plt.ylabel('Overall Installs')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The selection of the bar chart was based on its ability to clearly and easily display the distribution of total installations across different app categories. For categorical comparisons like these, where each category (e.g., Games, Education, Social) represents a separate section, bar charts are very helpful since they make it simple to visually order categories by their total downloads.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The app categories with the most total installs are shown in this chart. By highlighting the top downloaded categories on the Google Play Store, it shows consumer demand and preferences. This distribution makes it simple to detect both low-performing categories and high-performing categories (like Games and Social) that get the most installations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This knowledge is helpful for expanding a firm because:
#
# Strategic Focus: It enables the company to give high-demand sectors top priority for investment, which might increase revenue.
# Market Gaps: Finding categories with fewer installations may highlight untapped potential where customised advertising or app improvements might boost user engagement.
# User Engagement: By concentrating on well-liked categories, companies may create features that better suit user interests and increase customer happiness and retention.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
plt.figure(figsize=(10, 6))
sns.scatterplot(data=App_DATA, x='Size', y='Rating', alpha=0.6)
plt.title('App_Size vs. Rating')
plt.xlabel('App_Size')
plt.ylabel('Ratings')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The scatter plot was used to illustrate the association between App Size and Rating because it provides a good visual representation of the interaction between two continuous variables. When demonstrating correlations or patterns between variables, such as whether greater or smaller app sizes are associated with higher user ratings, scatter plots are perfect.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This graph shows if there is a relationship between an app's size and Google Play Store rating. One may ascertain if, for example, smaller applications often earn higher ratings or whether there is a particular range of app sizes linked to better user evaluations by looking at the distribution of data points. It could provide groups or trends that point to the ideal range of app sizes for increased user happiness.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Indeed, the information in this chart can have a beneficial effect on the expansion of a corporation because
#
# App Size Optimisation: Developers may aim to increase user happiness by focussing on app sizes that are linked to higher ratings.
# Improved User Experience: In areas where device storage is scarce, consumers may be less concerned about storage issues when using smaller or better-optimized apps, which will increase overall usability and retention.
# Product Quality Control: Development teams may utilise the information in this chart to help them balance the size and functionality of apps, perhaps improving performance without sacrificing user satisfaction.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
plt.figure(figsize=(10, 6))
sns.boxplot(data=App_DATA, x='Type', y='Rating')
plt.title('Price vs. Rating (Free vs Paid Apps)')
plt.xlabel('App Type (Free/Paid)')
plt.ylabel('Rating')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Because it efficiently illustrates the distribution of ratings for each category (free and paid), the box plot was used to compare ratings between free and paid applications. When displaying data dispersion, medians, and possible outliers, box plots are very helpful in highlighting variations in user satisfaction among app categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The rating differences between free and premium applications are seen in this chart. One may determine whether premium applications often obtain higher or worse ratings than free apps by looking at the median, quartiles, and any outliers. This can assist in determining if consumers believe that premium applications are of greater quality or whether free apps provide similar levels of pleasure.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Finding the Ideal App Size: By highlighting any size range associated with higher ratings, the scatter plot directs development towards sizes that optimise user engagement and pleasure.
#
# Large programs with Low Ratings: If consumers tend to dislike larger programs that demand a lot of storage space without providing any value, this might affect retention and downloads.
#
# Feature Bloat Risk: If there isn't a clear relationship between size and rating, it might mean that adding further features to an app doesn't increase user contentment, wasting money and stunting growth.
#
# Inconsistent Quality Across Sizes: If consumers believe that the developer's apps vary in quality, a large range of ratings for various app sizes may undermine user confidence and lead to churn.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
plt.figure(figsize=(8, 8))
top_categories = App_DATA['Category'].value_counts().head(10)
plt.pie(top_categories, labels=top_categories.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 10 Apps')
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pie chart is useful for visualising the proportional distribution of categorical data, in this example the number of apps by category. Because the purpose is to showcase the top ten app categories and their volume market share, a pie chart allows you to easily compare each category's proportion to the overall total. It is especially beneficial here since it rapidly communicates which categories are dominating.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The figure depicts the top ten app categories and their respective percentages of the total. This allows us to determine which categories have the greatest parts, which helps us assess the demand for different sorts of apps. For example, if categories like "Games" or "Productivity" have a substantial share, it suggests a high volume of offers and possibly considerable customer interest in these areas.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these findings might have a favourable business impact. Knowing which categories are most popular allows businesses to better align their product offerings or marketing efforts with consumer demand. For example, if the "Health & Fitness" category has a high representation, a firm might prioritise investing in related applications to enter that market.
#
# On the other side, findings might point to probable negative growth. For example, if the "Games" category dominates, this may imply a saturated market. Entering a crowded category may result in more competition and a lesser probability of garnering user attention, highlighting the importance of care while investing in such categories.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


features_extracted = ['Rating', 'Size', 'Installs', 'Price', 'Reviews']

correlation = App_DATA[features_extracted].corr()


plt.figure(figsize=(15, 9))

sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)


plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap is useful for understanding the correlations between numerical characteristics in a dataset. This heatmap uses colour intensities to graphically illustrate the correlation matrix of important metrics (such as Rating, Size, Installs, Price, and Reviews), allowing you to quickly spot significant positive or negative relationships. The colour gradient highlights strong and low correlations, providing fast understanding into patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The correlation heatmap shows the degree and direction of the associations between the features. For example:
#
# A strong positive connection between installations and Reviews indicates that programs with more installations have more user reviews, which is expected but useful to validate.
# Low or negative correlations, such as those between Price and Installs, may suggest that more expensive apps receive fewer downloads, implying a preference for free or inexpensive programs.
# These information can help inform strategic decisions about app price, feature focus, and user acquisition techniques.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
import seaborn as sns
import matplotlib.pyplot as plt


features = ['Rating', 'Size', 'Installs', 'Price', 'Reviews']


sns.pairplot(App_DATA[features])

plt.suptitle('Pair Plot', y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot is used to visualise relationships between numerous pairs of numerical information at the same time. This map displays probable linear or non-linear connections, distributions, and correlations between parameters such as Rating, Size, Installs, Price, and Reviews. It provides a full picture of all pairwise interactions, which might uncover hidden patterns or clusters within the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pair plot displays diagonal distributions as well as scatter plots for each paired feature combination. These insights might include:
#
# Patterns or clusters between Installs and Reviews, indicating a positive link in which more installs typically result in more reviews.
# The distributions of attributes like as Rating and Price illustrate how values are distributed, which might suggest user preferences or app-market trends.
# Potential outliers in attributes like Price may suggest uncommon, high-priced apps that break from the overall trend.
# These insights assist in understanding how characteristics interact and behave together, showing patterns and finding outliers.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# To attain the business goal, I recommend that the client focus on the following tactics.
#
# Optimise App Pricing: According to research, free or low-cost applications have greater install rates. To attract more users, particularly in competitive categories, think about giving free versions with in-app purchases or a freemium model. This strategy can increase reach while allowing for monetisation through upgrades.
#
# Improve User Ratings and Reviews: Apps with higher ratings and more reviews tend to get more installations. The client should prioritise user experience enhancements, actively solicit feedback, and encourage good evaluations. Adding features based on user preferences will boost app ratings and overall success.
#
# Target High-Demand Categories: Choosing popular categories from top-ranked segments helps increase installations. However, when addressing crowded markets, distinctiveness is critical. Offering distinctive features or focussing on particular subcategories might give a competitive advantage.
#
# Data-Driven Marketing: Incorporate insights from installations, reviews, and other analytics into marketing initiatives. For example, if certain populations favour specific categories or price ranges, customise advertisements to these groups. Monitoring installations and engagement data will assist in refining and optimising marketing campaigns.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.
#
# Conclusion This project is a detailed study of Play Store app data, providing developers with useful information in today's competitive mobile app environment. Using data manipulation tools and visualisations, we discovered patterns that influence app success. The findings of this study not only improve our understanding of user preferences, but also help developers make strategic decisions in app design, marketing, and user engagement. The study's findings can help developers optimise their applications for better performance and customer happiness in the Android marketplace. As the app ecosystem evolves, continuous analysis of user data will be critical to sustaining competitiveness and success.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
